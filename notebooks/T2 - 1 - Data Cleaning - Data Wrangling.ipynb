# %% [markdown]
# # Data Wrangling - La cirugía de los datos

# %% [markdown]
# **Data wrangling**, sometimes referred to as **data munging**, is the process of transforming and mapping data from one "raw" data form into another format with the intent of making it more appropriate and valuable for a variety of downstream purposes such as analytics. A **data wrangler** is a person who performs these transformation operations.
#
# This may include further munging, data visualization, data aggregation, training a statistical model, as well as many other potential uses. Data munging as a process typically follows a set of general steps which begin with extracting the data in a raw form from the data source, "munging" the raw data using algorithms (e.g. sorting) or parsing the data into predefined data structures, and finally depositing the resulting content into a data sink for storage and future use.

# %%
import pandas as pd

# %%
data = pd.read_csv("../datasets/customer-churn-model/Customer Churn Model.txt")

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %% [markdown]
# ## Crear un subconjunto de datos

# %%
accouunt_lenth = data["Account Length"]
accouunt_lenth.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
type(accouunt_lenth)
# Out:
# pandas.core.series.Series

# %%
subset = data[["Account Length", "Phone", "Eve Charge", "Day Calls"]]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %%
desired_columns = ["Account Length", "Phone", "Eve Charge", "Day Calls"]
subset = data[desired_columns]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
desired_columns = ["Account Length", "VMail Message", "Day Calls"]
desired_columns
# Out:
# ['Account Length', 'VMail Message', 'Day Calls']

# %%
all_columns_list = data.columns.values.tolist()
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
sublist = [x for x in all_columns_list if x not in desired_columns]
sublist
# Out:
# ['State',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
subset = data[sublist]
subset.head()
# Out:
#   State  Area Code     Phone Int'l Plan VMail Plan  Day Mins  Day Charge  \
# 0    KS        415  382-4657         no        yes     265.1       45.07
# 1    OH        415  371-7191         no        yes     161.6       27.47
# 2    NJ        415  358-1921         no         no     243.4       41.38
# 3    OH        408  375-9999        yes         no     299.4       50.90
# 4    OK        415  330-6626        yes         no     166.7       28.34
#
#    Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  Night Charge  \
# 0     197.4         99       16.78       244.7           91         11.01
# 1     195.5        103       16.62       254.4          103         11.45
# 2     121.2        110       10.30       162.6          104          7.32
# 3      61.9         88        5.26       196.9           89          8.86
# 4     148.3        122       12.61       186.9          121          8.41
#
#    Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# ...

# %%
data[10:20]
# Out:
#    State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 10    IN              65        415  329-6603         no         no
# 11    RI              74        415  344-9403         no         no
# 12    IA             168        408  363-1107         no         no
# 13    MT              95        510  394-8006         no         no
# 14    IA              62        415  366-9238         no         no
# 15    NY             161        415  351-7269         no         no
# 16    ID              85        408  350-8884         no        yes
# 17    VT              93        510  386-2923         no         no
# 18    VA              76        510  356-2992         no        yes
# 19    TX              73        415  373-2782         no         no
#
#     VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 10              0     129.1        137       21.95   ...           83
# 11              0     187.7        127       31.91   ...          148
# ...

# %%
# Usuarios con Day Mins > 500
data1 = data[data["Day Mins"] > 300]
print(data1.shape)
data1.head()
# Out:
# (43, 21)
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 76     DC              82        415  374-5353         no         no
# 156    OH              83        415  370-9116         no         no
# 197    TX             208        510  378-3625         no         no
# 230    MD              93        408  360-3324        yes         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 15               0     332.9         67       56.59   ...           97
# 76               0     300.3        109       51.05   ...          100
# 156              0     337.4        120       57.36   ...          116
# 197              0     326.5         67       55.51   ...          113
# 230              0     312.0        109       53.04   ...          100
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
# Usuarios de Nueva York (State = "NY")
data2 = data[data["State"]=="NY"]
print(data2.shape)
data2.head()
# Out:
# (83, 21)
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 77     NY             144        408  360-1171         no         no
# 136    NY              75        415  374-8525         no        yes
# 182    NY              67        408  405-2888         no        yes
# 186    NY             106        408  422-1471         no         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 15               0     332.9         67       56.59   ...           97
# 77               0      61.6        117       10.47   ...           85
# 136             21     175.8         97       29.89   ...          106
# 182             36     115.6        111       19.65   ...           94
# 186              0     158.7         74       26.98   ...          139
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
# AND -> &
data3 = data[(data["Day Mins"]> 300) & (data["State"]=="NY")]
print(data3.shape)
data3.head()
# Out:
# (2, 21)
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 985    NY              64        415  345-9140        yes         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 15               0     332.9         67       56.59   ...           97
# 985              0     346.8         55       58.96   ...           79
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 15        27.01       160.6          128          7.23        5.4           9
# 985       21.21       275.4          102         12.39       13.3           9
#
#      Intl Charge  CustServ Calls  Churn?
# 15          1.46               4   True.
# 985         3.59               1   True.
#
# [2 rows x 21 columns]

# %%
# OR -> |
data4 = data[(data["Day Mins"]> 300) | (data["State"]=="NY")]
print(data4.shape)
data4.head()
# Out:
# (124, 21)
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 76     DC              82        415  374-5353         no         no
# 77     NY             144        408  360-1171         no         no
# 136    NY              75        415  374-8525         no        yes
# 156    OH              83        415  370-9116         no         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 15               0     332.9         67       56.59   ...           97
# 76               0     300.3        109       51.05   ...          100
# 77               0      61.6        117       10.47   ...           85
# 136             21     175.8         97       29.89   ...          106
# 156              0     337.4        120       57.36   ...          116
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
data5 = data[data["Day Calls"]<data["Night Calls"]]
print(data5.shape)
data5.head()
# Out:
# (1626, 21)
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
# 5    AL             118        510  391-8027        yes         no
# 6    MA             121        510  355-9993         no        yes
# 7    MO             147        415  329-9001        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
# 5              0     223.4         98       37.98   ...          101
# 6             24     218.2         88       37.09   ...          108
# 7              0     157.0         79       26.69   ...           94
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
data5 = data[data["Day Mins"]<data["Night Mins"]]
print(data5.shape)
data5.head()
# Out:
# (2051, 21)
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 1    OH             107        415  371-7191         no        yes
# 4    OK              75        415  330-6626        yes         no
# 7    MO             147        415  329-9001        yes         no
# 8    LA             117        408  335-4719         no         no
# 9    WV             141        415  330-8173        yes        yes
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 1             26     161.6        123       27.47   ...          103
# 4              0     166.7        113       28.34   ...          122
# 7              0     157.0         79       26.69   ...           94
# 8              0     184.5         97       31.37   ...           80
# 9             37     258.6         84       43.96   ...          111
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
# Minutos de día, de noche y longitud de la cuenta de los primeros 50 individuos.
subset_first_50 = data[["Day Mins", "Night Mins", "Account Length"]][:50]
subset_first_50.head()
# Out:
#    Day Mins  Night Mins  Account Length
# 0     265.1       244.7             128
# 1     161.6       254.4             107
# 2     243.4       162.6             137
# 3     299.4       196.9              84
# 4     166.7       186.9              75

# %%
data.ix[1:10, 3:6] # Primeras 10 filas, columnas de la 3 a la 6.
# Out:
# /home/elugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#        Phone Int'l Plan VMail Plan
# 1   371-7191         no        yes
# 2   358-1921         no         no
# 3   375-9999        yes         no
# 4   330-6626        yes         no
# 5   391-8027        yes         no
# 6   355-9993         no        yes
# 7   329-9001        yes         no
# 8   335-4719         no         no
# 9   330-8173        yes        yes
# 10  329-6603         no         no

# %%
data.iloc[1:10, 3:6]
# Out:
#       Phone Int'l Plan VMail Plan
# 1  371-7191         no        yes
# 2  358-1921         no         no
# 3  375-9999        yes         no
# 4  330-6626        yes         no
# 5  391-8027        yes         no
# 6  355-9993         no        yes
# 7  329-9001        yes         no
# 8  335-4719         no         no
# 9  330-8173        yes        yes

# %%
data.iloc[:, 3:6] # Todas las filas y las columnas entre la 3 y la 6.
data.iloc[1:10, :] # Todas las columnas para las filas de la 1 a la 10.

# %%
data.iloc[1:10, [2,5,7]]
# Out:
#    Area Code VMail Plan  Day Mins
# 1        415        yes     161.6
# 2        415         no     243.4
# 3        408         no     299.4
# 4        415         no     166.7
# 5        510         no     223.4
# 6        510        yes     218.2
# 7        415         no     157.0
# 8        408         no     184.5
# 9        415        yes     258.6

# %%
data.iloc[[1, 5, 8, 36], [2, 5, 7]]
# Out:
#     Area Code VMail Plan  Day Mins
# 1         415        yes     161.6
# 5         510         no     223.4
# 8         408         no     184.5
# 36        408        yes     146.3

# %%
data.loc[10:15, ["Area Code", "Day Mins", "Night Mins"]]
# Out:
#     Area Code  Day Mins  Night Mins
# 10        415     129.1       208.8
# 11        415     187.7       196.0
# 12        408     128.8       141.1
# 13        510     156.6       192.3
# 14        415     120.7       203.0
# 15        415     332.9       160.6

# %%
data["Total Mins"] = data["Day Mins"] + data["Night Mins"] + data["Eve Mins"]

# %%
data["Total Mins"].head()
# Out:
# 0    707.2
# 1    611.5
# 2    527.2
# 3    558.2
# 4    501.9
# Name: Total Mins, dtype: float64

# %%
data[["Day Mins", "Eve Mins", "Night Mins", "Total Mins"]].head()
# Out:
#    Day Mins  Eve Mins  Night Mins  Total Mins
# 0     265.1     197.4       244.7       707.2
# 1     161.6     195.5       254.4       611.5
# 2     243.4     121.2       162.6       527.2
# 3     299.4      61.9       196.9       558.2
# 4     166.7     148.3       186.9       501.9

# %%
data["Total Calls"] = data["Day Calls"] + data["Night Calls"] + data["Eve Calls"]

# %%
data["Total Calls"].head()
# Out:
# 0    300
# 1    329
# 2    328
# 3    248
# 4    356
# Name: Total Calls, dtype: int64

# %%
data[["Day Calls", "Eve Calls", "Night Calls", "Total Calls"]].head()
# Out:
#    Day Calls  Eve Calls  Night Calls  Total Calls
# 0        110         99           91          300
# 1        123        103          103          329
# 2        114        110          104          328
# 3         71         88           89          248
# 4        113        122          121          356
